# %% [markdown]
# # Preview

# %% [markdown]
# **파이썬 언어의 특징**
#
#     - 간결한 문법
#     - interperter
#     - 다양한 프로그래밍 패러다임 지원: 절차적, 객체지향적, 함수형
#     - 플랫폼 독립성: 다양한 운영체제에서 동일한 코드로 가능
#     - 풍부한 라이브러리
#
# **기본 문법 목차**
#
#     - 자료형
#         - 정수형
#         - 문자열
#         - 리스트
#         - 튜플
#         - 딕셔너리
#         - Bool
#     - 연산자
#     - 조건문
#     - 반복문
#     - 모듈과 패키지
#     - 클래스

# %% [markdown]
# # 자료형

# %% [markdown]
# ## 리스트

# %%
# 리스트 인덱스
a = [1,2,3,4,5,6]

# 인덱싱 1개
print(a[0]) # 1

# 인덱싱 여러개 [시작: 끝]인데 끝보다 하나 앞까지 표시
print(a[0:3]) # [1,2,3]
print(a[5:]) # [6]
print(a[-1]) # 6 

# 인덱싱 시직:끝:step
print(a[::-1])
# Out:
# 1
# [1, 2, 3]
# [6]
# 6
# [6, 5, 4, 3, 2, 1]

# %%
# 몫, 소수점 있음
x = 14 / 3
print(x, type(x))

# 나머지
y = 10 % 3
print(y)

# 몫, 소수점 절삭 
z = 7 // 3
print(z, type(z))
# Out:
# 4.666666666666667 <class 'float'>
# 1
# 2 <class 'int'>

# %%
# 문자열 연결 오류
eng = 80
result = '영어점수 ' + eng + '점'
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 # 문자열 연결 오류
#       2 eng = 80
# ----> 3 result = '영어점수 ' + eng + '점'
#       4 print(result)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# 문자열 연결 오류 해결
# 방안 1
eng = "80"
result = '영어점수 ' + eng + '점'
print(result)

# 방안 2
eng = 80
result = '영어점수 ' + str(eng) + '점'
print(result)
# Out:
# 영어점수 80점
# 영어점수 80점

# %% [markdown]
# **문자열 포맷팅**
# 1. " % " % 변수명
# - %s : 문자열
# - %d : 숫자(정수)
# - %2d : 2번과 같되, 앞서의 숫자를 주면 너비를 뜻한다.
# - %05d : 3번과 같되, 채우고 싶은 문자가 0인 것이다.
# - %.2f: 소수점 둘째 자리의 숫자(실수)
# - %%: 문자를 문자열 내에서 사용하고 싶을 때
#
# 2. "{}".format(변수명)
# 3. f"{변수명}"

# %%
year = 2020
month = 3
day = 5
a = "%d-%02d-%02d"%(year,month,day)
print(a)
# Out:
# 2020-03-05

# %%
height = 172.5
a = "키는 %.2f입니다." % height
print(a)
# Out:
# 키는 172.50입니다.

# %%
# sep를 활용한 출력
year = 2020
month = 3
day = 5

print(year, month, day, sep='/')
# Out:
# 2020/3/5

# %%
a = "Hello"
b = "World"

# end를 활용한 문장 연결
print(a, end=" ")
print(b)
# Out:
# Hello World

# %%
# Q1-4.py

# %% [markdown]
# ## 튜플

# %%
tuple1 = ('banana', 'apple', 'cherry')
tuple2 = ('orange', 'pear', 'melon')

tuple3 = tuple1 + tuple2

print(tuple3)

del tuple1

# print(tuple1)
print(tuple2)
print(tuple3) # 당연히..그대로지....
# Out:
# ('banana', 'apple', 'cherry', 'orange', 'pear', 'melon')
# ('orange', 'pear', 'melon')
# ('banana', 'apple', 'cherry', 'orange', 'pear', 'melon')

# %%
dans = (2,3,4,5,6,7,8,9)
print('구구단표')

print("-"*30)
for d in dans:
    for i in range(1,10):
        print("%d x %d = %d" % (d, i ,d*i))

print("-"*30)
# Out:
# 구구단표
# ------------------------------
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# 8 x 9 = 72
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81
# ------------------------------

# %%
def average(*scores):
    sum = 0
    for i in range(len(scores)):
        sum += scores[i]
    avg = sum/len(scores)
    print("%d과목의 평균: %.2f" % (len(scores), avg))

average(90,80,100)
average(70, 93, 28, 90)
average(59, 67, 83, 80, 90)
# Out:
# 3과목의 평균: 90.00
# 4과목의 평균: 70.25
# 5과목의 평균: 75.80

# %%
def func

# %%
# 전역변수 > 지역변수
# 지역변수에서 전역변수를 변경하려고 해도, 그 값은 지역에서만 존재하고, 전역에서는 변경되지 않는다.
# 특히, 전역변수에서 이미 변경을 하면 이는 지역에 반영 X

# %%
class MyClass:
    def __init__(self, number):
        self.number = number
    
    def inc_10(self):
        self.number += 10

    def inc_20(self):
        self.number += 20


obj1 = MyClass(100)
obj1.inc_10()
obj1.inc_20()
print(obj1.number)

obj2 = MyClass(200)
obj2.inc_10()
obj2.inc_20()
print(obj2.number)
# Out:
# 130
# 230

# %%
class EngSentence:
    def __init__(self, sentence):
        self.sentence = sentence
        self.length = len(self.sentence)
    
    def reverse(self):
        tmp = ''
        for i in range(self.length):
            tmp += (self.sentence[self.length-1 - i])
        return tmp

    def insertHypen(self):
        tmp = ''
        for i in range(self.length):
            if self.sentence[i] == " " :
                tmp += '-'
            else:
                tmp += self.sentence[i]
        return tmp


a = "We are the champions!"
eng1 = EngSentence(a)
print("역순: %s" % eng1.reverse())
print("하이픈(-) 삽입: %s" % eng1.insertHypen())
# Out:
# 역순: !snoipmahc eht era eW
# 하이픈(-) 삽입: We-are-the-champions!

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def

# %%
import csv

# %% [markdown]
# ## 파일 읽고 쓰기

# %%
f = open('month_temp.csv', 'r', encoding='utf-8')
lines = csv.reader(f)
print("%s %s %s %s" % ('일자', '최저기온', '최고기온', '일교차'))

next(lines) # next 함수는 iterator로 해당 리스트의 다음을 불러오는 역할을 함

for line in lines:
    diff = float(line[4]) - float(line[3])
    print('%s %.1f %.1f %.1f' % (line[1], float(line[3]), float(line[4]), diff))

f.close()
# Out:
# 일자 최저기온 최고기온 일교차
# 2019-10-01 15.7 27.4 11.7
# 2019-10-02 20.4 23.8 3.4
# 2019-10-03 19.9 27.8 7.9
# 2019-10-04 17.8 26.9 9.1
# 2019-10-05 15.7 22.0 6.3
# 2019-10-06 14.0 22.0 8.0
# 2019-10-07 13.4 17.9 4.5
# 2019-10-08 10.7 20.6 9.9
# 2019-10-09 6.4 19.6 13.2
# 2019-10-10 9.5 20.2 10.7
# 2019-10-11 12.1 24.8 12.7
# 2019-10-12 14.1 23.3 9.2
# 2019-10-13 12.5 22.9 10.4
# 2019-10-14 8.5 19.4 10.9
# 2019-10-15 7.3 19.6 12.3
# 2019-10-16 7.9 20.0 12.1
# 2019-10-17 9.1 20.6 11.5
# 2019-10-18 10.0 21.9 11.9
# 2019-10-19 10.4 22.2 11.8
# 2019-10-20 10.8 21.7 10.9
# 2019-10-21 9.5 23.9 14.4
# 2019-10-22 11.1 23.0 11.9
# 2019-10-23 12.4 20.0 7.6
# 2019-10-24 14.1 23.3 9.2
# 2019-10-25 10.7 21.7 11.0
# 2019-10-26 6.4 13.9 7.5
# 2019-10-27 3.0 16.8 13.8
# 2019-10-28 6.3 17.4 11.1
# 2019-10-29 8.2 18.1 9.9
# 2019-10-30 3.3 17.1 13.8
# 2019-10-31 7.3 20.4 13.1

# %%
file1 = open('month_temp.csv', 'r', encoding='utf-8')
file2 = open('month_temp2.csv', 'w', encoding='utf-8', newline="")

lines = csv.reader(file1)
wr = csv.writer(file2)

wr.writerow(['일자', '최저기온', '최고기온', '일교차'])
next(lines)

for line in lines:
    diff = float(line[4]) - float(line[3])
    diff = format(diff, ".1f")
    wr.writerow([line[1], float(line[3]), float(line[4]), diff])

f.close()

# %%
f = open('pharm_2019.csv', 'r', encoding='utf-8')

lines = csv.reader(f)

header = next(lines)

city = "원주시"
total = 0
recent = 0

for line in lines:
    if line[1] == city:
        total += 1
    if int(line[3]) > 20140901:
        recent += 1

print("%s의 약국 수 : %d" % (city, total))
print("5년이내 개설된 약국 수 : %d개" % recent)
# Out:
# 원주시의 약국 수 : 156
# 5년이내 개설된 약국 수 : 8039개

# %%
import csv

f = open('pharm_2019.csv', 'r', encoding='utf-8')

lines = csv.reader(f)

header = next(lines)
print('번호', header[1], header[0], header[4], header[5], sep=',' )

number = 1
for line in lines:
    if ('경상북도' in line[2]) and (20100202 <= int(line[3]) <= 20201231):
        print("%d." % number, end=' ') #print(number, '.', sep='', end= ' ')
        print(line[1], line[0], line[4], line[5], sep='/')
        number+=1

f.close()
# Out:
# 번호,지역,약국명,경도,위도
# 1. 구미시/터미널약국/128.3506497/36.1227473
# 2. 경산시/천마약국/128.7572309/35.8397984
# 3. 경산시/중방약국/128.7360760/35.8303321
# 4. 포항남구/이동약국/129.3414690/36.0255358
# 5. 성주군/혜민약국/128.2871592/35.9185954
# 6. 경산시/옵티마제일약국/128.7355074/35.8234177
# 7. 포항북구/굿모닝약국/129.3497366/36.1086807
# 8. 포항북구/영천온누리약국/129.3836663/36.0824353
# 9. 김천시/비보약국/128.1726603/36.1069718
# 10. 구미시/옥계21세기약국/128.4202436/36.1382147
# 11. 경산시/골드팜행복나눔약국/128.7272621/35.8346110
# 12. 경산시/구약국/128.7364283/35.8283577
# 13. 구미시/동산약국/128.3151874/36.1386284
# 14. 포항북구/양덕건강한약국/129.3971357/36.0831931
# 15. 문경시/아름다운약국/128.2037365/36.6025369
# 16. 구미시/소망약국/128.4167299/36.1371643
# 17. 구미시/평화약국/128.3631750/36.1221487
# 18. 칠곡군/대백미소약국/128.3982431/35.9817152
# 19. 포항북구/늘사랑약국/129.3754548/36.0597963
# 20. 김천시/솔빛약국/128.1880263/36.1214666
# 21. 영덕군/참약국/129.3685696/36.4112459
# 22. 경주시/성동약국/129.2160590/35.8446239
# 23. 포항북구/나을약국/129.3447884/36.1077895
# 24. 포항북구/참좋은약국/129.3809604/36.0672943
# 25. 경산시/새별약국/128.7376086/35.8242493
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
with open('jeju_2019.csv', 'r', encoding='utf-8') as f:
    lines = csv.reader(f)
    next(lines)

    sum_rain = [0] * 12
    
    for line in lines:
        month = int(line[2][5:7]) - 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
humanities = []
for line in lines:
    if line[1] == "고산" and int(line[2][5:7]) == month:
        humidies.append(float(line[6]))

# %%
with open('jeju_2019.csv', 'r', encoding='utf-8') as f:
    lines = csv.reader(f)
    header = next(lines)

    total_rain = {'제주': 0, '고산':0, '성산':0, '서귀포':0}
    
    for line in lines:
        rain = float(line[5] or 0)
        total_rain[line[1]] += rain

    # max_area = [k for k,v in total_rain.items() if max(total_rain.values()) == v]
    
    # max_year_rain = 0
    # max_area = ''
    # for area, rain in total_rain.items():
    #     if max_year_rain <= rain:
    #         max_year_rain = rain
    #         max_area = area
    
    max_area = max(total_rain, key=total_rain.get)
    max_year_rain = total_rain[max_area]

print(max_area, max_year_rain)
# Out:
# 성산 2658.100000000001

# %%
with open('jeju_2019.csv', 'r', encoding='utf-8') as f:
    lines = csv.reader(f)
    header = next(lines)

    total_rain = {'제주': 0, '고산':0, '성산':0, '서귀포':0}
    
    for line in lines:
        rain = float(line[5] or 0)
        total_rain[line[1]] += rain
    
    max_area = max(total_rain, key=total_rain.get)
    max_year_rain = total_rain[max_area]


print(f"(1) 연 강수 최대 지역: {max_area}")
print("(2) 지역별 강수량")
for area, rain in total_rain.items():
    print(f"{area}: {format(rain, '.1f')}mm")
# Out:
# (1) 연 강수 최대 지역: 성산
# (2) 지역별 강수량
# 제주: 1979.9mm
# 고산: 1560.9mm
# 성산: 2658.1mm
# 서귀포: 2210.3mm

# %% [markdown]
# ## Decorator

# %% [markdown]
# 동일한 코드가 중복될 때, 반복될 때 많이 사용하게 된다.

# %%
def my_decorator(func):
    def wrapper():
        print("함수 실행 전")
        func()
        print("함수 실행 후")
    
    return wrapper

@my_decorator
def hello():
    print("Hello, Python")

hello()
# Out:
# 함수 실행 전
# Hello, Python
# 함수 실행 후

# %%
def my_decorator(func):
    def wrapper(*args, **kwargs):
        print()

# %% [markdown]
# ### 파이썬 함수 정의 순서
#
# 최종적으로 호출할때 모두 정의되어 있기만 하면 순서는 상관이없다..

# %%
def func1():
    func2()  # 실행 시점에서는 func2가 이미 정의됨

def func2():
    print("Hello from func2!")

# 실행은 마지막에 그러면 함수 정의 순서 상관없이 가능함.
func1()
# Out:
# Hello from func2!
